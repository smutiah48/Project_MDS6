# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %%
# Ganti dengan API key Anda.
api_key = 'AIzaSyDStK-DXk13eTOb6s1DJzsF4ZRoh-YC_GU'

# Contoh pencarian buku dengan judul "Statistik".
search_term = "Statistika"
max_results = 40  # Maksimum adalah 40
url = f"https://www.googleapis.com/books/v1/volumes?q={search_term}&maxResults={max_results}&key={api_key}"

# Melakukan permintaan ke Google Books API.
response = requests.get(url)
data = response.json()

# Siapkan list untuk menampung data buku.
books = []

# Analisis data dan ekstraksi informasi jika item tersedia.
if 'items' in data:
    for item in data['items']:
        book_id = item['id']
        book_title = item['volumeInfo']['title']
        book_authors = item['volumeInfo'].get('authors', [])
        book_categories = ', '.join(item['volumeInfo'].get('categories', [])) if 'categories' in item['volumeInfo'] else 'Kategori tidak tersedia'
        book_publisher = item['volumeInfo'].get('publisher', 'Penerbit tidak tersedia')
        book_published_date = item['volumeInfo'].get('publishedDate', 'Tanggal terbit tidak tersedia')
        book_page_count = item['volumeInfo'].get('pageCount', 'Jumlah halaman tidak tersedia')
        book_isbn = [isbn['identifier'] for isbn in item['volumeInfo'].get('industryIdentifiers', []) if isbn['type'] == 'ISBN_13']
        book_isbn = book_isbn[0] if book_isbn else 'ISBN tidak tersedia'
        book_link = item['volumeInfo'].get('infoLink', 'Link buku tidak tersedia')
        book_description = item['volumeInfo'].get('description', 'Deskripsi tidak tersedia')
        # Tempat penerbit sebagai placeholder
        book_publisher_location = "Informasi tidak tersedia"

        # Menambahkan data ke list books.
        books.append({
            'ID Buku': book_id,
            'Judul': book_title,
            'Penulis': ', '.join(book_authors),
            'Kategori': book_categories,
            'Nama Penerbit': book_publisher,
            'Tempat Penerbit': book_publisher_location,  # Placeholder untuk lokasi penerbit
            'Tahun Terbit': book_published_date,
            'Jumlah Halaman': book_page_count,
            'ISBN': book_isbn,
            'Link Buku': book_link,
            'Deskripsi': book_description
        })

    # Membuat DataFrame dari list buku.
    books_df = pd.DataFrame(books)

    # Menampilkan DataFrame.
    display(books_df)
else:
    print("Tidak ada hasil yang ditemukan.")

# Jika ingin menyimpan ke file CSV:
# books_df.to_csv('books.csv', index=False)
# Out:
#          ID Buku                                              Judul  \
# 0   pM5GDwAAQBAJ                              Statistika Pendidikan
# 1   Ec4OEAAAQBAJ                               Statistika Pendidkan
# 2   HVFKEAAAQBAJ                                      Biostatistika
# 3   VK--EAAAQBAJ                                 Statistika Ekonomi
# 4   imf5DwAAQBAJ                Pengantar Statistika (Edisi Ketiga)
# 5   C1bKEAAAQBAJ                                 STATISTIKA EKONOMI
# 6   qmvDVYJsa2MC  Statistika Deskriptif dalam Bidang Ekonomi dan...
# 7   DNtTeajDy30C                      Dasar Dasar Metode Statistika
# 8   eCWPBpRGP9YC  Teknik Statistika untuk Bisnis & Ekonomi, edis...
# 9   saZED8D4mpsC         Metode statistika untuk bisnis dan ekonomi
# 10  YNliEAAAQBAJ                                         STATISTIKA
# 11  kmHMDwAAQBAJ                              Statistika Deskriptif
# 12  ZRdQDwAAQBAJ                                 Statistika Terapan
# 13  ubVVDwAAQBAJ                              Statistika Pendidikan
# 14  ReRVDwAAQBAJ                                 Statistika Ekonomi
# 15  Afb1EAAAQBAJ                              STATISTIKA PENDIDIKAN
# 21        9786238382231  https://play.google.com/store/books/details?id...
# 22        9786230116360  https://play.google.com/store/books/details?id...
# 23        9786235400075  https://play.google.com/store/books/details?id...
# 24        9786237247609  https://play.google.com/store/books/details?id...
# 25        9786236177358  https://play.google.com/store/books/details?id...
# 26        9786026930545  https://play.google.com/store/books/details?id...
# 27        9786236103456  https://play.google.com/store/books/details?id...
# 28        9786024323639  https://play.google.com/store/books/details?id...
# 29        9786237636267  http://books.google.co.id/books?id=Fi0MEAAAQBA...
# 30        9786235298382  https://play.google.com/store/books/details?id...
# 31        9786235274089  https://play.google.com/store/books/details?id...
# 32        9786024757922  https://play.google.com/store/books/details?id...
# 33        9786024320799  https://play.google.com/store/books/details?id...
# 34        9786021036204  https://play.google.com/store/books/details?id...
# 35        9786231331731  https://play.google.com/store/books/details?id...
# 36        9786024322373  https://play.google.com/store/books/details?id...
# 37        9786232093959  https://play.google.com/store/books/details?id...
# 38        9786024226213  https://play.google.com/store/books/details?id...
# 39        9786238863112  https://play.google.com/store/books/details?id...
#
#                                             Deskripsi
# 0   Buku teks ini disusun di tengah-tengah kegelis...
# 1   Buku Statistika Pendidikan ini memberikan pema...
# 2   Buku ajar Statistika ini ditujukan untuk memen...
# 3   Pada abad ke-20, penggunaan statistika dalam e...
# 4   Manusia dalam hidupnya tidak dapat memisahkan ...
# 5   Statistika adalah kumpulan fakta berupa angka ...
# 6                            Deskripsi tidak tersedia
# 7                            Deskripsi tidak tersedia
# 8                            Deskripsi tidak tersedia
# 9                            Deskripsi tidak tersedia
# 10  Buku ajar ini disusun dengan tujuan untuk dapa...
# 11  Cakupan materi yang dipelajari dalam buku Stat...
# 12  """Buku Statistika dalam konteks penerapan pad...
# 13  Buku statistik ini berisikan ringkasan materi ...
# 14  Sistematika materi yang ditulis dalam buku ini...
# 15  Statistika mempunyai peranan yang cukup pentin...
# 16  Selama ini orang mengasosiasikan kata ‘statist...
# 17  Buku ajar ini memiliki beberapa perbedaan diba...
# 18  Statistika berperan penting membantu mahasiswa...
# 19  Buku "Statistika Dasar : Teori dan Konsep Dasa...
# 20  Buku ini khusus membahas tentang penerapan ana...
# 21  Pengantar Statistika adalah disiplin ilmu yang...
# 22  Statistik digunakan dalam semua bidang ilmu. P...
# 23  Statistika Untuk Ilmu Sosial merupakan langkah...
# 24                           Deskripsi tidak tersedia
# 25  Statistika merupakan seperangkat metode yang s...
# 26  Statiska adalah salah satu alat yang dapat dij...
# 27  Bagi pembelajar bidang ilmu non esakta, statis...
# 28  Buku ini disusun dalam 12 bab yang dikelompokk...
# 29                           Deskripsi tidak tersedia
# 30  Mata kuliah statistika dan perancangan eksperi...
# 31  Statistika banyak diterapkan dalam berbagai il...
# 32  Statistik menurut Susetyo (2010:3) adalah seku...
# 33  Buku berjudul PEMODELAN STATISTIKA PADA ANALIS...
# 34  Tidak ada yang menampik bahwa statistika merup...
# 35  Dalam bab ini akan dibahas mengenai aplikasi a...
# 36                           Deskripsi tidak tersedia
# 37  Menurut definisi yang diberikan oleh Gliner da...
# 38  Penulisan buku ini didorong dari pengalaman me...
# 39  Ada beberapa pembagian statistika, salah satun...

# %%
books_df.to_csv('books statistik.csv', index=False)
